# %% [markdown]
# # CSI 4142 : F1 Engine Performance Project

# %% [markdown]
# ### 1.Reference Document
#
# > [Project Plan](https://docs.google.com/spreadsheets/d/1MfZ_uWyq5k1WNh2hdbd9T7jhoByZJO3L/edit?usp=sharing&ouid=111189071097712478456&rtpof=true&sd=true)
#
# > [Delivrable 2](https://docs.google.com/document/d/1QaYq-9d9uC2lt160PFkPMVZOqoBR38ypDO2FrSrDs9s/edit?usp=sharing)
#
#
# > [Dataset Schema](https://drawsql.app/teams/hee-1/diagrams/f1)

# %% [markdown]
# ## 1. General Information
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 1.2. Tips and useful panda commands
#
#
# *   `df = pd.read_csv('path_to_your_file.csv')` : Use to read the csv file
# *   `df` : display the content of the dataframe
# *   `print(df.dtypes)` : Print a Series with the data type of each column
# *   `df.head(5)` : only display the first 5 element of the dataframe

# %% [markdown]
# ## 1. Upload Datasets from your drive

# %%
# !pip install google-auth
# !pip install --upgrade pandas
# Out:
# Requirement already satisfied: google-auth in /usr/local/lib/python3.10/dist-packages (2.27.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth) (4.9)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth) (0.5.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Collecting pandas
#   Downloading pandas-2.2.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 23.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.25.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.4)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.4/345.4 kB 18.1 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Installing collected packages: tzdata, pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.5.3
#     Uninstalling pandas-1.5.3:
#       Successfully uninstalled pandas-1.5.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==1.5.3, but you have pandas 2.2.1 which is incompatible.
# Successfully installed pandas-2.2.1 tzdata-2024.1

# %%
from google.colab import auth
auth.authenticate_user()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Check if Colab has now access to your Drive

# %%
# !ls '/content/drive/My Drive'
# Out:
#  Bail			    Menja
#  Capstone.pdf		   'Mika Rafaralahy - Cover Letter - Navblue.gdoc'
# 'Careers and Jobs.gsheet'   Musique
# 'Carte Consulaire'	   "Permis d'étude"
# 'Coding assesments'	   'Rapport COOP'
# 'Colab Google'		    RedBubble
# 'Colab Notebooks'	    Report_mrafa099.pdf
#  CV			    STG-44
#  Dataset		   'Story Telling'
# 'Etsy plans'		    Taxe
# 'Etsy - Report.gsheet'	   'Untitled document.gdoc'
# 'Facture Vehicule'	   'Untitled spreadsheet.gsheet'
#  Iphones		    uOttawa
# 'Madagascar Books'	   'Vente Voiture'

# %% [markdown]
# ## 2. Data Test and Panda initilization

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Testing with a constructor_result.csv file to make sure that ***panda*** was correctly imported and files are accessible

# %% [markdown]
# **Note**: Don't forget to create a Dataset folder in your google Drive and to upload the different datasets in there

# %%
df = pd.read_csv('/content/drive/My Drive/Dataset/constructor_results.csv')
df
# Out:
#        constructorResultsId  raceId  constructorId  points status
# 0                         1      18              1    14.0     \N
# 1                         2      18              2     8.0     \N
# 2                         3      18              3     9.0     \N
# 3                         4      18              4     5.0     \N
# 4                         5      18              5     2.0     \N
# ...                     ...     ...            ...     ...    ...
# 12285                 16785    1110            214    10.0     \N
# 12286                 16786    1110            213     1.0     \N
# 12287                 16787    1110             51     0.0     \N
# 12288                 16788    1110              3     0.0     \N
# 12289                 16789    1110            210     0.0     \N
#
# [12290 rows x 5 columns]

# %%
df = pd.read_csv('/content/drive/My Drive/Dataset/constructors.csv')
df
# Out:
#      constructorId constructorRef            name nationality  \
# 0                1        mclaren         McLaren     British
# 1                2     bmw_sauber      BMW Sauber      German
# 2                3       williams        Williams     British
# 3                4        renault         Renault      French
# 4                5     toro_rosso      Toro Rosso     Italian
# ..             ...            ...             ...         ...
# 206            209          manor  Manor Marussia     British
# 207            210           haas    Haas F1 Team    American
# 208            211   racing_point    Racing Point     British
# 209            213     alphatauri      AlphaTauri     Italian
# 210            214         alpine  Alpine F1 Team      French
#
#                                                    url
# 0                 http://en.wikipedia.org/wiki/McLaren
# 1              http://en.wikipedia.org/wiki/BMW_Sauber
# 2    http://en.wikipedia.org/wiki/Williams_Grand_Pr...
# 3    http://en.wikipedia.org/wiki/Renault_in_Formul...
# 4     http://en.wikipedia.org/wiki/Scuderia_Toro_Rosso
# ..                                                 ...
# 206      http://en.wikipedia.org/wiki/Manor_Motorsport
# 207          http://en.wikipedia.org/wiki/Haas_F1_Team
# 208  http://en.wikipedia.org/wiki/Racing_Point_F1_Team
# 209   http://en.wikipedia.org/wiki/Scuderia_AlphaTauri
# 210        http://en.wikipedia.org/wiki/Alpine_F1_Team
#
# [211 rows x 5 columns]

# %% [markdown]
# ## 3. Dataset Loading

# %%
races = pd.read_csv('/content/drive/My Drive/Dataset/races.csv')
results = pd.read_csv('/content/drive/My Drive/Dataset/results.csv')
lap_times = pd.read_csv('/content/drive/My Drive/Dataset/lap_times.csv')
drivers = pd.read_csv('/content/drive/My Drive/Dataset/drivers.csv', encoding = 'utf-8')
constructors = pd.read_csv('/content/drive/My Drive/Dataset/constructors.csv')
circuits = pd.read_csv('/content/drive/My Drive/Dataset/circuits.csv')
seasons = pd.read_csv('/content/drive/My Drive/Dataset/seasons.csv')
constructor_results = pd.read_csv('/content/drive/My Drive/Dataset/constructor_results.csv')
sprint_results = pd.read_csv('/content/drive/My Drive/Dataset/sprint_results.csv')
print("RACES")
print("-----------------------")
print(races.dtypes)
print("-----------------------")
print("RESULTS")
print("-----------------------")
print(results.dtypes)
print("-----------------------")
print("LAP TIMES")
print("-----------------------")
print(lap_times.dtypes)
print("-----------------------")
print("DRIVERS")
print("-----------------------")
print(drivers.dtypes)
print("-----------------------")
print("CONSTRUCTORS")
print("-----------------------")
print(constructors.dtypes)
print("-----------------------")
print("CONSTRUCTOR RESULTS")
print("-----------------------")
print(constructor_results.dtypes)
print("-----------------------")
print("SPRINT RESULTS")
print("-----------------------")
print(sprint_results.dtypes)
# Out:
# RACES
# -----------------------
# raceId          int64
# year            int64
# round           int64
# circuitId       int64
# name           object
# date           object
# time           object
# url            object
# fp1_date       object
# fp1_time       object
# fp2_date       object
# fp2_time       object
# fp3_date       object
# fp3_time       object
# quali_date     object
# quali_time     object
# sprint_date    object
# sprint_time    object
# dtype: object
# -----------------------
# RESULTS
# -----------------------
# resultId             int64
# raceId               int64
# driverId             int64
# constructorId        int64
# number              object
# grid                 int64
# position            object
# positionText        object
# positionOrder        int64
# points             float64
# laps                 int64
# time                object
# milliseconds        object
# fastestLap          object
# rank                object
# fastestLapTime      object
# fastestLapSpeed     object
# statusId             int64
# dtype: object
# -----------------------
# LAP TIMES
# -----------------------
# raceId           int64
# driverId         int64
# lap              int64
# position         int64
# time            object
# milliseconds     int64
# dtype: object
# -----------------------
# DRIVERS
# -----------------------
# driverId        int64
# driverRef      object
# number         object
# code           object
# forename       object
# surname        object
# dob            object
# nationality    object
# url            object
# dtype: object
# -----------------------
# CONSTRUCTORS
# -----------------------
# constructorId      int64
# constructorRef    object
# name              object
# nationality       object
# url               object
# dtype: object
# -----------------------
# CONSTRUCTOR RESULTS
# -----------------------
# constructorResultsId      int64
# raceId                    int64
# constructorId             int64
# points                  float64
# status                   object
# dtype: object
# -----------------------
# SPRINT RESULTS
# -----------------------
# resultId           int64
# raceId             int64
# driverId           int64
# constructorId      int64
# number             int64
# grid               int64
# position          object
# positionText      object
# positionOrder      int64
# points             int64
# laps               int64
# time              object
# milliseconds      object
# fastestLap        object
# fastestLapTime    object
# statusId           int64
# dtype: object

# %% [markdown]
# Let's see what cunstructors have the most races

# %%
constructors_count = results['constructorId'].value_counts()
constructors_count
# Out:
# constructorId
# 6      2371
# 1      1855
# 3      1609
# 25      881
# 32      871
#        ...
# 96        1
# 93        1
# 153       1
# 84        1
# 123       1
# Name: count, Length: 210, dtype: int64

# %%
constructor1 = constructors[constructors['constructorId'] == 6].name
print("constructor 1: " + constructor1)
constructor2 = constructors[constructors['constructorId'] == 1].name
print("constructor 2: " + constructor2)
constructor3 = constructors[constructors['constructorId'] == 131].name
print("constructor 3: " + constructor3)
# Out:
# 5    constructor 1: Ferrari
# Name: name, dtype: object
# 0    constructor 2: McLaren
# Name: name, dtype: object
# 129    constructor 3: Mercedes
# Name: name, dtype: object

# %%
results[results['constructorId'] == 6].describe()
# Out:
#            resultId       raceId     driverId  constructorId         grid  \
# count   2371.000000  2371.000000  2371.000000         2371.0  2371.000000
# mean   13859.975538   570.042176   232.389709            6.0     6.273302
# std     7722.387634   313.325792   256.332094            0.0     4.783538
# min        8.000000     1.000000     4.000000            6.0     0.000000
# 25%     6793.500000   297.000000    22.000000            6.0     3.000000
# 50%    15368.000000   598.000000   117.000000            6.0     5.000000
# 75%    19985.000000   818.500000   385.000000            6.0     8.000000
# max    26084.000000  1110.000000   844.000000            6.0    31.000000
#
#        positionOrder       points         laps     statusId
# count    2371.000000  2371.000000  2371.000000  2371.000000
# mean        8.338676     4.343429    51.529734    10.210881
# std         6.965347     5.375949    24.765198    21.033654
# min         1.000000     0.000000     0.000000     1.000000
# 25%         3.000000     0.000000    36.000000     1.000000
# 50%         6.000000     3.000000    56.000000     1.000000
# 75%        13.000000     8.000000    70.000000    11.000000
# max        33.000000    26.000000   110.000000   135.000000

# %%
race_info_df = pd.merge(races, results[['raceId', 'laps']], on='raceId', how='left')
race_info_df
# Out:
#        raceId  year  round  circuitId                      name        date  \
# 0           1  2009      1          1     Australian Grand Prix  2009-03-29
# 1           1  2009      1          1     Australian Grand Prix  2009-03-29
# 2           1  2009      1          1     Australian Grand Prix  2009-03-29
# 3           1  2009      1          1     Australian Grand Prix  2009-03-29
# 4           1  2009      1          1     Australian Grand Prix  2009-03-29
# ...       ...   ...    ...        ...                       ...         ...
# 26085    1116  2023     18         69  United States Grand Prix  2023-10-22
# 26086    1117  2023     19         32    Mexico City Grand Prix  2023-10-29
# 26087    1118  2023     20         18      São Paulo Grand Prix  2023-11-05
# 26088    1119  2023     21         80      Las Vegas Grand Prix  2023-11-19
# 26089    1120  2023     22         24      Abu Dhabi Grand Prix  2023-11-26
#
#            time                                                url  \
# 0      06:00:00  http://en.wikipedia.org/wiki/2009_Australian_G...
# 1      06:00:00  http://en.wikipedia.org/wiki/2009_Australian_G...
# 2      06:00:00  http://en.wikipedia.org/wiki/2009_Australian_G...
# 3      06:00:00  http://en.wikipedia.org/wiki/2009_Australian_G...
# 4      06:00:00  http://en.wikipedia.org/wiki/2009_Australian_G...
# ...         ...                                                ...
# 26085  19:00:00  https://en.wikipedia.org/wiki/2023_United_Stat...
# 26086  20:00:00  https://en.wikipedia.org/wiki/2023_Mexico_City...
# 26087  17:00:00  https://en.wikipedia.org/wiki/2023_S%C3%A3o_Pa...
# 26088  06:00:00  https://en.wikipedia.org/wiki/2023_Las_Vegas_G...
# 26089  13:00:00  https://en.wikipedia.org/wiki/2023_Abu_Dhabi_G...
#
#          fp1_date  fp1_time    fp2_date  fp2_time    fp3_date  fp3_time  \
# 0              \N        \N          \N        \N          \N        \N
# 1              \N        \N          \N        \N          \N        \N
# 2              \N        \N          \N        \N          \N        \N
# 3              \N        \N          \N        \N          \N        \N
# 4              \N        \N          \N        \N          \N        \N
# ...           ...       ...         ...       ...         ...       ...
# 26085  2023-10-20  17:30:00  2023-10-21  18:00:00          \N        \N
# 26086  2023-10-27  18:30:00  2023-10-27  22:00:00  2023-10-28  17:30:00
# 26087  2023-11-03  14:30:00  2023-11-04  14:30:00          \N        \N
# 26088  2023-11-17  04:30:00  2023-11-17  08:00:00  2023-11-18  04:30:00
# 26089  2023-11-24  09:30:00  2023-11-24  13:00:00  2023-11-25  10:30:00
#
#        quali_date quali_time sprint_date sprint_time  laps
# 0              \N         \N          \N          \N  58.0
# 1              \N         \N          \N          \N  58.0
# 2              \N         \N          \N          \N  58.0
# 3              \N         \N          \N          \N  58.0
# 4              \N         \N          \N          \N  58.0
# ...           ...        ...         ...         ...   ...
# 26085  2023-10-20   21:00:00  2023-10-21    22:00:00   NaN
# 26086  2023-10-28   21:00:00          \N          \N   NaN
# 26087  2023-11-03   18:00:00  2023-11-04    18:30:00   NaN
# 26088  2023-11-18   08:00:00          \N          \N   NaN
# 26089  2023-11-25   14:00:00          \N          \N   NaN
#
# [26090 rows x 19 columns]

# %%
results
# Out:
#        resultId  raceId  driverId  constructorId number  grid position  \
# 0             1      18         1              1     22     1        1
# 1             2      18         2              2      3     5        2
# 2             3      18         3              3      7     7        3
# 3             4      18         4              4      5    11        4
# 4             5      18         5              1     23     3        5
# ...         ...     ...       ...            ...    ...   ...      ...
# 26075     26081    1110       817            213      3    19       16
# 26076     26082    1110       858              3      2    18       17
# 26077     26083    1110       807            210     27     0       18
# 26078     26084    1110       832              6     55     4       \N
# 26079     26085    1110       857              1     81     5       \N
#
#       positionText  positionOrder  points  laps         time milliseconds  \
# 0                1              1    10.0    58  1:34:50.616      5690616
# 1                2              2     8.0    58       +5.478      5696094
# 2                3              3     6.0    58       +8.163      5698779
# 3                4              4     5.0    58      +17.181      5707797
# 4                5              5     4.0    58      +18.014      5708630
# ...            ...            ...     ...   ...          ...          ...
# 26075           16             16     0.0    44    +1:43.071      5053521
# 26076           17             17     0.0    44    +1:44.476      5054926
# 26077           18             18     0.0    44    +1:50.450      5060900
# 26078            R             19     0.0    23           \N           \N
# 26079            R             20     0.0     0           \N           \N
#
#       fastestLap rank fastestLapTime fastestLapSpeed  statusId
# 0             39    2       1:27.452         218.300         1
# 1             41    3       1:27.739         217.586         1
# 2             41    5       1:28.090         216.719         1
# 3             58    7       1:28.603         215.464         1
# 4             43    1       1:27.418         218.385         1
# ...          ...  ...            ...             ...       ...
# 26075         25   15       1:50.994         227.169         1
# 26076         37    9       1:50.486         228.213         1
# 26077         26    4       1:49.907         229.415         1
# 26078          9   19       1:53.138         222.864       130
# 26079         \N    0             \N              \N       130
#
# [26080 rows x 18 columns]

# %% [markdown]
# # 4. Dimensions Staging

# %% [markdown]
# ### race_lap_dimenension

# %% [markdown]
# Let's sort races by year and laps by raceId

# %%
races = races.sort_values(by = "year")
laps = lap_times.sort_values(by = "raceId")
races.head(100)
# Out:
#      raceId  year  round  circuitId                      name        date  \
# 838     839  1950      7         14        Italian Grand Prix  1950-09-03
# 837     838  1950      6         55         French Grand Prix  1950-07-02
# 836     837  1950      5         13        Belgian Grand Prix  1950-06-18
# 835     836  1950      4         66          Swiss Grand Prix  1950-06-04
# 834     835  1950      3         19          Indianapolis 500  1950-05-30
# ..      ...   ...    ...        ...                       ...         ...
# 744     745  1961      8         46  United States Grand Prix  1961-10-08
# 741     742  1961      5         58        British Grand Prix  1961-07-15
# 740     741  1961      4         55         French Grand Prix  1961-07-02
# 738     739  1961      2         39          Dutch Grand Prix  1961-05-22
# 737     738  1961      1          6         Monaco Grand Prix  1961-05-14
#
#     time                                                url fp1_date fp1_time  \
# 838   \N  http://en.wikipedia.org/wiki/1950_Italian_Gran...       \N       \N
# 837   \N  http://en.wikipedia.org/wiki/1950_French_Grand...       \N       \N
# 836   \N  http://en.wikipedia.org/wiki/1950_Belgian_Gran...       \N       \N
# 835   \N  http://en.wikipedia.org/wiki/1950_Swiss_Grand_...       \N       \N
# 834   \N  http://en.wikipedia.org/wiki/1950_Indianapolis...       \N       \N
# ..   ...                                                ...      ...      ...
# 744   \N  http://en.wikipedia.org/wiki/1961_United_State...       \N       \N
# 741   \N  http://en.wikipedia.org/wiki/1961_British_Gran...       \N       \N
# 740   \N  http://en.wikipedia.org/wiki/1961_French_Grand...       \N       \N
# 738   \N  http://en.wikipedia.org/wiki/1961_Dutch_Grand_...       \N       \N
# 737   \N  http://en.wikipedia.org/wiki/1961_Monaco_Grand...       \N       \N
#
#     fp2_date fp2_time fp3_date fp3_time quali_date quali_time sprint_date  \
# 838       \N       \N       \N       \N         \N         \N          \N
# 837       \N       \N       \N       \N         \N         \N          \N
# 836       \N       \N       \N       \N         \N         \N          \N
# 835       \N       \N       \N       \N         \N         \N          \N
# 834       \N       \N       \N       \N         \N         \N          \N
# ..       ...      ...      ...      ...        ...        ...         ...
# 744       \N       \N       \N       \N         \N         \N          \N
# 741       \N       \N       \N       \N         \N         \N          \N
# 740       \N       \N       \N       \N         \N         \N          \N
# 738       \N       \N       \N       \N         \N         \N          \N
# 737       \N       \N       \N       \N         \N         \N          \N
#
#     sprint_time
# 838          \N
# 837          \N
# 836          \N
# 835          \N
# 834          \N
# ..          ...
# 744          \N
# 741          \N
# 740          \N
# 738          \N
# 737          \N
#
# [100 rows x 18 columns]

# %%
laps.head(100)
# Out:
#         raceId  driverId  lap  position      time  milliseconds
# 342881       1         1    1        13  1:49.088        109088
# 343543       1        20   21         2  1:46.868        106868
# 343544       1        20   22         2  2:38.375        158375
# 343545       1        20   23         2  2:31.909        151909
# 343546       1        20   24         2  2:22.185        142185
# ...        ...       ...  ...       ...       ...           ...
# 343575       1        20   53         2  1:29.721         89721
# 343576       1        20   54         2  1:30.237         90237
# 343577       1        20   55         2  1:31.092         91092
# 343578       1        20   56         7  2:40.783        160783
# 343579       1         3    1         6  1:42.659        102659
#
# [100 rows x 6 columns]

# %% [markdown]
# We keep only relevent columns of the races df

# %%
races = races.loc[:, ['raceId', 'year', 'name']]
#we can also use race.drop(labels=['year', 'round',	'circuitId',	'date',	'time', etc...], axis=1) but it's too long to type....
races
# Out:
#       raceId  year                      name
# 838      839  1950        Italian Grand Prix
# 837      838  1950         French Grand Prix
# 836      837  1950        Belgian Grand Prix
# 835      836  1950          Swiss Grand Prix
# 834      835  1950          Indianapolis 500
# ...      ...   ...                       ...
# 1080    1099  2023  Saudi Arabian Grand Prix
# 1079    1098  2023        Bahrain Grand Prix
# 1099    1119  2023      Las Vegas Grand Prix
# 1088    1108  2023        British Grand Prix
# 1100    1120  2023      Abu Dhabi Grand Prix
#
# [1101 rows x 3 columns]

# %% [markdown]
# Let's check if our df contains null data

# %%
races.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1101 entries, 838 to 1100
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   raceId  1101 non-null   int64
#  1   year    1101 non-null   int64
#  2   name    1101 non-null   object
# dtypes: int64(2), object(1)
# memory usage: 66.7+ KB

# %% [markdown]
# We notice that our df has no null data. All 1101 entrie are present.

# %% [markdown]
# We do the same with lap dimension

# %%
lap_times.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 551742 entries, 0 to 551741
# Data columns (total 6 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   raceId        551742 non-null  int64
#  1   driverId      551742 non-null  int64
#  2   lap           551742 non-null  int64
#  3   position      551742 non-null  int64
#  4   time          551742 non-null  object
#  5   milliseconds  551742 non-null  int64
# dtypes: int64(5), object(1)
# memory usage: 25.3+ MB

# %% [markdown]
# We also have no missing values in the laps dimension

# %% [markdown]
# Let's rename the columns in the lap df to match our dimensional model

# %%
lap_times = lap_times.rename(mapper={'lap': 'lap_number','milliseconds': 'time_milliseconds'}, axis=1)
lap_times.head(10)
# Out:
#    raceId  driverId  lap_number  position      time  time_milliseconds
# 0     841        20           1         1  1:38.109              98109
# 1     841        20           2         1  1:33.006              93006
# 2     841        20           3         1  1:32.713              92713
# 3     841        20           4         1  1:32.803              92803
# 4     841        20           5         1  1:32.342              92342
# 5     841        20           6         1  1:32.605              92605
# 6     841        20           7         1  1:32.502              92502
# 7     841        20           8         1  1:32.537              92537
# 8     841        20           9         1  1:33.240              93240
# 9     841        20          10         1  1:32.572              92572

# %% [markdown]
# **Note**: We noticed our lap_times dataset doesn't contain informations of speed/lap so we decided to drop that column from our race_lap_dimension

# %% [markdown]
# Let's change the time column type to timeDelta. This will allow us to be able to do calcultions on the time data

# %% [markdown]
# Let's clean the time column first

# %%
lap_times['time'].isnull().sum()
# Out:
# 0

# %%
lap_times['time'] = lap_times['time'].astype(str).str.replace(',', '.')

# %%
invalid_times = lap_times[~lap_times['time'].str.contains(':', regex=True)]
invalid_times.head()
# Out:
# Empty DataFrame
# Columns: [raceId, driverId, lap_number, position, time, time_milliseconds]
# Index: []

# %% [markdown]
# Standardising the time format

# %%
import re
lap_times['time'] = lap_times['time'].apply(lambda x: f'00:0{x}' if re.match(r'\d{1}:\d{2}\.\d{3}',x) else x).astype(str).str.strip()
lap_times['time'] = lap_times['time'].apply(lambda x: f'00:{x}' if re.match(r'\d{2}:\d{2}\.\d{3}',x) else x).astype(str).str.strip()
lap_times['time'] = lap_times['time'].apply(lambda x: f'0{x}' if re.match(r'\d{1}\:\d{2}\:\d{2}\.\d{3}',x) else x).astype(str).str.strip()
lap_times
# Out:
#         raceId  driverId  lap_number  position          time  \
# 0          841        20           1         1  00:01:38.109
# 1          841        20           2         1  00:01:33.006
# 2          841        20           3         1  00:01:32.713
# 3          841        20           4         1  00:01:32.803
# 4          841        20           5         1  00:01:32.342
# ...        ...       ...         ...       ...           ...
# 551737    1110       817          40        17  00:01:54.361
# 551738    1110       817          41        17  00:01:53.367
# 551739    1110       817          42        16  00:01:55.247
# 551740    1110       817          43        16  00:01:52.115
# 551741    1110       817          44        16  00:01:52.265
#
#         time_milliseconds
# 0                   98109
# 1                   93006
# 2                   92713
# 3                   92803
# 4                   92342
# ...                   ...
# 551737             114361
# 551738             113367
# 551739             115247
# 551740             112115
# 551741             112265
#
# [551742 rows x 6 columns]

# %% [markdown]
# Checking for anomalies

# %%
filtered_df = lap_times[~lap_times['time'].str.match(r'^\d{2}\:\d{2}:\d{2}\.\d{3}$')]
filtered_df
# Out:
# Empty DataFrame
# Columns: [raceId, driverId, lap_number, position, time, time_milliseconds]
# Index: []

# %%
def to_timedelta(s):
    h,m,seconds = s.split(':')
    seconds, milli = seconds.split('.', maxsplit=1)
    return pd.Timedelta(hours=int(h), minutes=int(m), seconds=int(seconds), milliseconds=int(milli))#+ str(0)

# %% [markdown]
# test

# %%
to_timedelta(lap_times['time'][1])
# Out:
# Timedelta('0 days 00:01:33.006000')

# %%
lap_times['time'] =  lap_times['time'].apply(to_timedelta)
lap_times.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 551742 entries, 0 to 551741
# Data columns (total 6 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   raceId             551742 non-null  int64
#  1   driverId           551742 non-null  int64
#  2   lap_number         551742 non-null  int64
#  3   position           551742 non-null  int64
#  4   time               551742 non-null  timedelta64[ns]
#  5   time_milliseconds  551742 non-null  int64
# dtypes: int64(5), timedelta64[ns](1)
# memory usage: 25.3 MB

# %% [markdown]
# Now let us join our race df and our lap_times df to create our dimension

# %%
lap_times = lap_times.loc[:, ['raceId', 'driverId', 'lap_number','position', 'time', 'time_milliseconds']]
lap_times
# Out:
#         raceId  driverId  lap_number  position                   time  \
# 0          841        20           1         1 0 days 00:01:38.109000
# 1          841        20           2         1 0 days 00:01:33.006000
# 2          841        20           3         1 0 days 00:01:32.713000
# 3          841        20           4         1 0 days 00:01:32.803000
# 4          841        20           5         1 0 days 00:01:32.342000
# ...        ...       ...         ...       ...                    ...
# 551737    1110       817          40        17 0 days 00:01:54.361000
# 551738    1110       817          41        17 0 days 00:01:53.367000
# 551739    1110       817          42        16 0 days 00:01:55.247000
# 551740    1110       817          43        16 0 days 00:01:52.115000
# 551741    1110       817          44        16 0 days 00:01:52.265000
#
#         time_milliseconds
# 0                   98109
# 1                   93006
# 2                   92713
# 3                   92803
# 4                   92342
# ...                   ...
# 551737             114361
# 551738             113367
# 551739             115247
# 551740             112115
# 551741             112265
#
# [551742 rows x 6 columns]

# %%
race_lap_dimension  = races.merge(lap_times, on='raceId')
race_lap_dimension
# Out:
#         raceId  year                   name  driverId  lap_number  position  \
# 0          224  1996  Australian Grand Prix        30           1         4
# 1          224  1996  Australian Grand Prix        30           2         3
# 2          224  1996  Australian Grand Prix        30           3         3
# 3          224  1996  Australian Grand Prix        30           4         3
# 4          224  1996  Australian Grand Prix        30           5         3
# ...        ...   ...                    ...       ...         ...       ...
# 551737    1108  2023     British Grand Prix       825          27        16
# 551738    1108  2023     British Grand Prix       825          28        15
# 551739    1108  2023     British Grand Prix       825          29        15
# 551740    1108  2023     British Grand Prix       825          30        14
# 551741    1108  2023     British Grand Prix       825          31        14
#
#                          time  time_milliseconds
# 0      0 days 00:01:45.188000             105188
# 1      0 days 00:01:37.680000              97680
# 2      0 days 00:01:35.759000              95759
# 3      0 days 00:01:35.467000              95467
# 4      0 days 00:01:35.254000              95254
# ...                       ...                ...
# 551737 0 days 00:01:33.935000              93935
# 551738 0 days 00:01:33.760000              93760
# 551739 0 days 00:01:33.356000              93356
# 551740 0 days 00:01:33.466000              93466
# 551741 0 days 00:01:33.464000              93464
#
# [551742 rows x 8 columns]

# %% [markdown]
# **We noticed that our dataset is missing values from years 1950 to 1995. still, this doesn't affect the purpose of our project**

# %%
race_lap_dimension.head(50)
# Out:
#     raceId  year                   name  driverId  lap_number  position  \
# 0      224  1996  Australian Grand Prix        30           1         4
# 1      224  1996  Australian Grand Prix        30           2         3
# 2      224  1996  Australian Grand Prix        30           3         3
# 3      224  1996  Australian Grand Prix        30           4         3
# 4      224  1996  Australian Grand Prix        30           5         3
# 5      224  1996  Australian Grand Prix        30           6         3
# 6      224  1996  Australian Grand Prix        30           7         3
# 7      224  1996  Australian Grand Prix        30           8         3
# 8      224  1996  Australian Grand Prix        30           9         3
# 9      224  1996  Australian Grand Prix        30          10         3
# 10     224  1996  Australian Grand Prix        30          11         3
# 11     224  1996  Australian Grand Prix        30          12         3
# 12     224  1996  Australian Grand Prix        30          13         3
# 13     224  1996  Australian Grand Prix        30          14         3
# 14     224  1996  Australian Grand Prix        30          15         3
# 15     224  1996  Australian Grand Prix        30          16         3
# 16     224  1996  Australian Grand Prix        30          17         3
# 17     224  1996  Australian Grand Prix        30          18         3
# 18     224  1996  Australian Grand Prix        30          19         3
# 19     224  1996  Australian Grand Prix        30          20         4
# 20     224  1996  Australian Grand Prix        30          21         4
# 21     224  1996  Australian Grand Prix        30          22         3
# 22     224  1996  Australian Grand Prix        30          23         3
# 23     224  1996  Australian Grand Prix        30          24         3
# 24     224  1996  Australian Grand Prix        30          25         3
# 25     224  1996  Australian Grand Prix        30          26         3
# 26     224  1996  Australian Grand Prix        30          27         3
# 27     224  1996  Australian Grand Prix        30          28         3
# 28     224  1996  Australian Grand Prix        30          29         3
# 29     224  1996  Australian Grand Prix        30          30         3
# 30     224  1996  Australian Grand Prix        30          31         3
# 31     224  1996  Australian Grand Prix        30          32         9
# 32     224  1996  Australian Grand Prix        56           1         3
# 33     224  1996  Australian Grand Prix        56           2         4
# 34     224  1996  Australian Grand Prix        56           3         4
# 35     224  1996  Australian Grand Prix        56           4         4
# 36     224  1996  Australian Grand Prix        56           5         4
# 37     224  1996  Australian Grand Prix        56           6         4
# 38     224  1996  Australian Grand Prix        56           7         4
# 39     224  1996  Australian Grand Prix        56           8         4
# 40     224  1996  Australian Grand Prix        56           9         4
# 41     224  1996  Australian Grand Prix        56          10         4
# 42     224  1996  Australian Grand Prix        56          11         4
# 43     224  1996  Australian Grand Prix        56          12         4
# 44     224  1996  Australian Grand Prix        56          13         4
# 45     224  1996  Australian Grand Prix        56          14         4
# 46     224  1996  Australian Grand Prix        56          15         4
# 47     224  1996  Australian Grand Prix        56          16         4
# 48     224  1996  Australian Grand Prix        56          17         4
# 49     224  1996  Australian Grand Prix        56          18         4
#
#                      time  time_milliseconds
# 0  0 days 00:01:45.188000             105188
# 1  0 days 00:01:37.680000              97680
# 2  0 days 00:01:35.759000              95759
# 3  0 days 00:01:35.467000              95467
# 4  0 days 00:01:35.254000              95254
# 5  0 days 00:01:35.117000              95117
# 6  0 days 00:01:35.023000              95023
# 7  0 days 00:01:35.407000              95407
# 8  0 days 00:01:35.198000              95198
# 9  0 days 00:01:35.088000              95088
# 10 0 days 00:01:34.631000              94631
# 11 0 days 00:01:34.310000              94310
# 12 0 days 00:01:34.389000              94389
# 13 0 days 00:01:34.302000              94302
# 14 0 days 00:01:34.390000              94390
# 15 0 days 00:01:34.223000              94223
# 16 0 days 00:01:34.617000              94617
# 17 0 days 00:01:33.651000              93651
# 18 0 days 00:01:33.771000              93771
# 19 0 days 00:02:01.619000             121619
# 20 0 days 00:01:39.239000              99239
# 21 0 days 00:01:34.742000              94742
# 22 0 days 00:01:36.444000              96444
# 23 0 days 00:01:34.996000              94996
# 24 0 days 00:01:34.408000              94408
# 25 0 days 00:01:34.081000              94081
# 26 0 days 00:01:36.842000              96842
# 27 0 days 00:01:36.526000              96526
# 28 0 days 00:01:38.304000              98304
# 29 0 days 00:01:39.485000              99485
# 30 0 days 00:01:39.354000              99354
# 31 0 days 00:03:02.162000             182162
# 32 0 days 00:01:44.981000             104981
# 33 0 days 00:01:38.558000              98558
# 34 0 days 00:01:36.736000              96736
# 35 0 days 00:01:36.177000              96177
# 36 0 days 00:01:36.093000              96093
# 37 0 days 00:01:35.942000              95942
# 38 0 days 00:01:36.061000              96061
# 39 0 days 00:01:35.448000              95448
# 40 0 days 00:01:35.830000              95830
# 41 0 days 00:01:36.681000              96681
# 42 0 days 00:01:35.669000              95669
# 43 0 days 00:01:35.309000              95309
# 44 0 days 00:01:35.284000              95284
# 45 0 days 00:01:35.590000              95590
# 46 0 days 00:01:35.266000              95266
# 47 0 days 00:01:35.378000              95378
# 48 0 days 00:01:35.337000              95337
# 49 0 days 00:01:35.100000              95100

# %%
race_lap_dimension = race_lap_dimension.sort_values(by='year', ascending=True)
race_lap_dimension
# Out:
#         raceId  year                   name  driverId  lap_number  position  \
# 0          224  1996  Australian Grand Prix        30           1         4
# 9614       234  1996      German Grand Prix        14          20         7
# 9615       234  1996      German Grand Prix        14          21         6
# 9616       234  1996      German Grand Prix        14          22         6
# 9617       234  1996      German Grand Prix        14          23         4
# ...        ...   ...                    ...       ...         ...       ...
# 542664    1107  2023    Austrian Grand Prix       855          31        14
# 542665    1107  2023    Austrian Grand Prix       855          32        14
# 542666    1107  2023    Austrian Grand Prix       855          33        14
# 542668    1107  2023    Austrian Grand Prix       855          35        14
# 551741    1108  2023     British Grand Prix       825          31        14
#
#                          time  time_milliseconds
# 0      0 days 00:01:45.188000             105188
# 9614   0 days 00:01:49.568000             109568
# 9615   0 days 00:01:48.693000             108693
# 9616   0 days 00:01:48.228000             108228
# 9617   0 days 00:01:47.907000             107907
# ...                       ...                ...
# 542664 0 days 00:01:11.779000              71779
# 542665 0 days 00:01:11.643000              71643
# 542666 0 days 00:01:11.503000              71503
# 542668 0 days 00:01:11.641000              71641
# 551741 0 days 00:01:33.464000              93464
#
# [551742 rows x 8 columns]

# %% [markdown]
# ### constructor_dimension

# %%
constructors =  constructors.sort_values(by='name')
constructors
# Out:
#      constructorId constructorRef        name nationality  \
# 145            147            afm         AFM      German
# 38              39            ags         AGS      French
# 52              54            ats         ATS     Italian
# 159            161          adams       Adams    American
# 49              51           alfa  Alfa Romeo       Swiss
# ..             ...            ...         ...         ...
# 105            107         watson      Watson    American
# 158            160      wetteroth   Wetteroth    American
# 2                3       williams    Williams     British
# 57              59           wolf        Wolf    Canadian
# 47              49       zakspeed    Zakspeed      German
#
#                                                    url
# 145  http://en.wikipedia.org/wiki/Alex_von_Falkenha...
# 38   http://en.wikipedia.org/wiki/Automobiles_Gonfa...
# 52           http://en.wikipedia.org/wiki/ATS_(wheels)
# 159   http://en.wikipedia.org/wiki/Adams_(constructor)
# 49   http://en.wikipedia.org/wiki/Alfa_Romeo_in_For...
# ..                                                 ...
# 105           http://en.wikipedia.org/wiki/A.J._Watson
# 158             http://en.wikipedia.org/wiki/Wetteroth
# 2    http://en.wikipedia.org/wiki/Williams_Grand_Pr...
# 57     http://en.wikipedia.org/wiki/Walter_Wolf_Racing
# 47               http://en.wikipedia.org/wiki/Zakspeed
#
# [211 rows x 5 columns]

# %% [markdown]
# Let's remove unecessary columns

# %%
constructors = constructors.drop(labels=['nationality', 'url'], axis=1)
constructors
# Out:
#      constructorId constructorRef        name
# 145            147            afm         AFM
# 38              39            ags         AGS
# 52              54            ats         ATS
# 159            161          adams       Adams
# 49              51           alfa  Alfa Romeo
# ..             ...            ...         ...
# 105            107         watson      Watson
# 158            160      wetteroth   Wetteroth
# 2                3       williams    Williams
# 57              59           wolf        Wolf
# 47              49       zakspeed    Zakspeed
#
# [211 rows x 3 columns]

# %% [markdown]
# Let's check if we have missing values

# %%
constructors['constructorRef'] = constructors['constructorRef'].astype(str).str.strip()
constructors['name'] = constructors['name'].astype(str).str.strip()
constructors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 211 entries, 145 to 47
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   constructorId   211 non-null    int64
#  1   constructorRef  211 non-null    object
#  2   name            211 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 6.6+ KB

# %% [markdown]
# We seem to have all the values we need.

# %% [markdown]
# Let's get the constructors by race

# %%
constructor_dimension = constructors
constructor_dimension
# Out:
#      constructorId constructorRef        name
# 145            147            afm         AFM
# 38              39            ags         AGS
# 52              54            ats         ATS
# 159            161          adams       Adams
# 49              51           alfa  Alfa Romeo
# ..             ...            ...         ...
# 105            107         watson      Watson
# 158            160      wetteroth   Wetteroth
# 2                3       williams    Williams
# 57              59           wolf        Wolf
# 47              49       zakspeed    Zakspeed
#
# [211 rows x 3 columns]

# %%
constructor_dimension.drop_duplicates(inplace=True)
constructor_dimension
# Out:
#      constructorId constructorRef        name
# 145            147            afm         AFM
# 38              39            ags         AGS
# 52              54            ats         ATS
# 159            161          adams       Adams
# 49              51           alfa  Alfa Romeo
# ..             ...            ...         ...
# 105            107         watson      Watson
# 158            160      wetteroth   Wetteroth
# 2                3       williams    Williams
# 57              59           wolf        Wolf
# 47              49       zakspeed    Zakspeed
#
# [211 rows x 3 columns]

# %% [markdown]
# ### season_dimension

# %% [markdown]
# Let's remove unecessary columns

# %%
seasons = seasons.drop(labels=['url'], axis=1).sort_values(by='year')
seasons
# Out:
#     year
# 60  1950
# 59  1951
# 58  1952
# 57  1953
# 56  1954
# ..   ...
# 69  2019
# 70  2020
# 71  2021
# 72  2022
# 73  2023
#
# [74 rows x 1 columns]

# %% [markdown]
# Let's check if we have missing values

# %%
seasons.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 74 entries, 60 to 73
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    74 non-null     int64
# dtypes: int64(1)
# memory usage: 1.2 KB

# %% [markdown]
# Let's add the engine column.

# %%
engine_specs = []

for year in seasons['year']:
    if year < 1966:
        engine_specs.append('1.5L')
    elif 1966 <= year <= 1986:
        engine_specs.append('3.0L')
    elif 1987 <= year <= 1988:
        engine_specs.append('1.5L Turbo')
    elif 1989 <= year <= 1994:
        engine_specs.append('3.5L')
    elif 1995 <= year <= 2005:
        engine_specs.append('3.0L V10')
    elif 2006 <= year <= 2013:
        engine_specs.append('2.4L V8')
    else:  # From 2014 onwards
        engine_specs.append('1.6L V6 Turbo Hybrid')

# Creating the DataFrame
season_dimension = pd.DataFrame({
    'year': seasons['year'],
    'engine': engine_specs
})

season_dimension
# Out:
#     year                engine
# 60  1950                  1.5L
# 59  1951                  1.5L
# 58  1952                  1.5L
# 57  1953                  1.5L
# 56  1954                  1.5L
# ..   ...                   ...
# 69  2019  1.6L V6 Turbo Hybrid
# 70  2020  1.6L V6 Turbo Hybrid
# 71  2021  1.6L V6 Turbo Hybrid
# 72  2022  1.6L V6 Turbo Hybrid
# 73  2023  1.6L V6 Turbo Hybrid
#
# [74 rows x 2 columns]

# %% [markdown]
# ### driver_dimension

# %%
drivers
# Out:
#      driverId        driverRef number code  forename     surname         dob  \
# 0           1         hamilton     44  HAM     Lewis    Hamilton  1985-01-07
# 1           2         heidfeld     \N  HEI      Nick    Heidfeld  1977-05-10
# 2           3          rosberg      6  ROS      Nico     Rosberg  1985-06-27
# 3           4           alonso     14  ALO  Fernando      Alonso  1981-07-29
# 4           5       kovalainen     \N  KOV    Heikki  Kovalainen  1981-10-19
# ..        ...              ...    ...  ...       ...         ...         ...
# 852       854  mick_schumacher     47  MSC      Mick  Schumacher  1999-03-22
# 853       855             zhou     24  ZHO    Guanyu        Zhou  1999-05-30
# 854       856         de_vries     21  DEV      Nyck    de Vries  1995-02-06
# 855       857          piastri     81  PIA     Oscar     Piastri  2001-04-06
# 856       858         sargeant      2  SAR     Logan    Sargeant  2000-12-31
#
#     nationality                                             url
# 0       British     http://en.wikipedia.org/wiki/Lewis_Hamilton
# 1        German      http://en.wikipedia.org/wiki/Nick_Heidfeld
# 2        German       http://en.wikipedia.org/wiki/Nico_Rosberg
# 3       Spanish    http://en.wikipedia.org/wiki/Fernando_Alonso
# 4       Finnish  http://en.wikipedia.org/wiki/Heikki_Kovalainen
# ..          ...                                             ...
# 852      German    http://en.wikipedia.org/wiki/Mick_Schumacher
# 853     Chinese        http://en.wikipedia.org/wiki/Zhou_Guanyu
# 854       Dutch      http://en.wikipedia.org/wiki/Nyck_de_Vries
# 855  Australian      http://en.wikipedia.org/wiki/Oscar_Piastri
# 856    American     http://en.wikipedia.org/wiki/Logan_Sargeant
#
# [857 rows x 9 columns]

# %%
drivers_constructors = results.loc[:, ['driverId', 'constructorId', 'raceId']]
drivers_constructors.drop_duplicates(inplace=True)
drivers_constructors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 26006 entries, 0 to 26079
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   driverId       26006 non-null  int64
#  1   constructorId  26006 non-null  int64
#  2   raceId         26006 non-null  int64
# dtypes: int64(3)
# memory usage: 812.7 KB

# %% [markdown]
# Let's remove unecessary columns

# %%
drivers_col_selected= drivers.drop(labels=['code', 'nationality', 'dob', 'url'], axis=1)

driver = drivers_col_selected

drivers_col_selected
# Out:
#      driverId        driverRef number  forename     surname
# 0           1         hamilton     44     Lewis    Hamilton
# 1           2         heidfeld     \N      Nick    Heidfeld
# 2           3          rosberg      6      Nico     Rosberg
# 3           4           alonso     14  Fernando      Alonso
# 4           5       kovalainen     \N    Heikki  Kovalainen
# ..        ...              ...    ...       ...         ...
# 852       854  mick_schumacher     47      Mick  Schumacher
# 853       855             zhou     24    Guanyu        Zhou
# 854       856         de_vries     21      Nyck    de Vries
# 855       857          piastri     81     Oscar     Piastri
# 856       858         sargeant      2     Logan    Sargeant
#
# [857 rows x 5 columns]

# %%
drivers_col_selected = drivers_col_selected.merge(drivers_constructors, on='driverId')
drivers_col_selected
# Out:
#        driverId driverRef number forename   surname  constructorId  raceId
# 0             1  hamilton     44    Lewis  Hamilton              1      18
# 1             1  hamilton     44    Lewis  Hamilton              1      19
# 2             1  hamilton     44    Lewis  Hamilton              1      20
# 3             1  hamilton     44    Lewis  Hamilton              1      21
# 4             1  hamilton     44    Lewis  Hamilton              1      22
# ...         ...       ...    ...      ...       ...            ...     ...
# 26001       858  sargeant      2    Logan  Sargeant              3    1106
# 26002       858  sargeant      2    Logan  Sargeant              3    1107
# 26003       858  sargeant      2    Logan  Sargeant              3    1108
# 26004       858  sargeant      2    Logan  Sargeant              3    1109
# 26005       858  sargeant      2    Logan  Sargeant              3    1110
#
# [26006 rows x 7 columns]

# %%
drivers_col_selected.drop_duplicates(inplace=True)
drivers_col_selected
# Out:
#        driverId driverRef number forename   surname  constructorId  raceId
# 0             1  hamilton     44    Lewis  Hamilton              1      18
# 1             1  hamilton     44    Lewis  Hamilton              1      19
# 2             1  hamilton     44    Lewis  Hamilton              1      20
# 3             1  hamilton     44    Lewis  Hamilton              1      21
# 4             1  hamilton     44    Lewis  Hamilton              1      22
# ...         ...       ...    ...      ...       ...            ...     ...
# 26001       858  sargeant      2    Logan  Sargeant              3    1106
# 26002       858  sargeant      2    Logan  Sargeant              3    1107
# 26003       858  sargeant      2    Logan  Sargeant              3    1108
# 26004       858  sargeant      2    Logan  Sargeant              3    1109
# 26005       858  sargeant      2    Logan  Sargeant              3    1110
#
# [26006 rows x 7 columns]

# %% [markdown]
# We're going to drop the "number" column because it has too many null values

# %%
drivers_dimension= drivers_col_selected.drop(labels=['number'], axis=1)
drivers_dimension
# Out:
#        driverId driverRef forename   surname  constructorId  raceId
# 0             1  hamilton    Lewis  Hamilton              1      18
# 1             1  hamilton    Lewis  Hamilton              1      19
# 2             1  hamilton    Lewis  Hamilton              1      20
# 3             1  hamilton    Lewis  Hamilton              1      21
# 4             1  hamilton    Lewis  Hamilton              1      22
# ...         ...       ...      ...       ...            ...     ...
# 26001       858  sargeant    Logan  Sargeant              3    1106
# 26002       858  sargeant    Logan  Sargeant              3    1107
# 26003       858  sargeant    Logan  Sargeant              3    1108
# 26004       858  sargeant    Logan  Sargeant              3    1109
# 26005       858  sargeant    Logan  Sargeant              3    1110
#
# [26006 rows x 6 columns]

# %%
Alonso_count = drivers_dimension[drivers_dimension['surname'] == 'Alonso']
Alonso_count
# Out:
#       driverId driverRef  forename surname  constructorId  raceId
# 712          4    alonso  Fernando  Alonso              4      18
# 713          4    alonso  Fernando  Alonso              4      19
# 714          4    alonso  Fernando  Alonso              4      20
# 715          4    alonso  Fernando  Alonso              4      21
# 716          4    alonso  Fernando  Alonso              4      22
# ...        ...       ...       ...     ...            ...     ...
# 1077         4    alonso  Fernando  Alonso            117    1106
# 1078         4    alonso  Fernando  Alonso            117    1107
# 1079         4    alonso  Fernando  Alonso            117    1108
# 1080         4    alonso  Fernando  Alonso            117    1109
# 1081         4    alonso  Fernando  Alonso            117    1110
#
# [370 rows x 6 columns]

# %% [markdown]
# Let's check if we have missing values

# %%
drivers_dimension.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26006 entries, 0 to 26005
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   driverId       26006 non-null  int64
#  1   driverRef      26006 non-null  object
#  2   forename       26006 non-null  object
#  3   surname        26006 non-null  object
#  4   constructorId  26006 non-null  int64
#  5   raceId         26006 non-null  int64
# dtypes: int64(3), object(3)
# memory usage: 1.2+ MB

# %%
drivers_dimension['driver_name'] = drivers_dimension['forename'].str.cat(drivers_dimension['surname'],sep=" ")
drivers_dimension.drop(columns=['forename', 'surname'], inplace=True)
drivers_dimension
# Out:
#        driverId driverRef  constructorId  raceId     driver_name
# 0             1  hamilton              1      18  Lewis Hamilton
# 1             1  hamilton              1      19  Lewis Hamilton
# 2             1  hamilton              1      20  Lewis Hamilton
# 3             1  hamilton              1      21  Lewis Hamilton
# 4             1  hamilton              1      22  Lewis Hamilton
# ...         ...       ...            ...     ...             ...
# 26001       858  sargeant              3    1106  Logan Sargeant
# 26002       858  sargeant              3    1107  Logan Sargeant
# 26003       858  sargeant              3    1108  Logan Sargeant
# 26004       858  sargeant              3    1109  Logan Sargeant
# 26005       858  sargeant              3    1110  Logan Sargeant
#
# [26006 rows x 5 columns]

# %% [markdown]
# ### 6. Other changes

# %% [markdown]
# add the constructor ID in the races_lap_dimension

# %%
temp = pd.merge(season_dimension, race_lap_dimension, on='year')
temp = temp.rename(mapper={'year': 'seasonId'}, axis=1)
temp
# Out:
#         seasonId                engine  raceId                   name  \
# 0           1996              3.0L V10     224  Australian Grand Prix
# 1           1996              3.0L V10     234      German Grand Prix
# 2           1996              3.0L V10     234      German Grand Prix
# 3           1996              3.0L V10     234      German Grand Prix
# 4           1996              3.0L V10     234      German Grand Prix
# ...          ...                   ...     ...                    ...
# 551737      2023  1.6L V6 Turbo Hybrid    1107    Austrian Grand Prix
# 551738      2023  1.6L V6 Turbo Hybrid    1107    Austrian Grand Prix
# 551739      2023  1.6L V6 Turbo Hybrid    1107    Austrian Grand Prix
# 551740      2023  1.6L V6 Turbo Hybrid    1107    Austrian Grand Prix
# 551741      2023  1.6L V6 Turbo Hybrid    1108     British Grand Prix
#
#         driverId  lap_number  position                   time  \
# 0             30           1         4 0 days 00:01:45.188000
# 1             14          20         7 0 days 00:01:49.568000
# 2             14          21         6 0 days 00:01:48.693000
# 3             14          22         6 0 days 00:01:48.228000
# 4             14          23         4 0 days 00:01:47.907000
# ...          ...         ...       ...                    ...
# 551737       855          31        14 0 days 00:01:11.779000
# 551738       855          32        14 0 days 00:01:11.643000
# 551739       855          33        14 0 days 00:01:11.503000
# 551740       855          35        14 0 days 00:01:11.641000
# 551741       825          31        14 0 days 00:01:33.464000
#
#         time_milliseconds
# 0                  105188
# 1                  109568
# 2                  108693
# 3                  108228
# 4                  107907
# ...                   ...
# 551737              71779
# 551738              71643
# 551739              71503
# 551740              71641
# 551741              93464
#
# [551742 rows x 9 columns]

# %%
temp = pd.merge(temp, drivers_dimension, on=['raceId','driverId'])
temp
# Out:
#         seasonId                engine  raceId                   name  \
# 0           1996              3.0L V10     224  Australian Grand Prix
# 1           1996              3.0L V10     234      German Grand Prix
# 2           1996              3.0L V10     234      German Grand Prix
# 3           1996              3.0L V10     234      German Grand Prix
# 4           1996              3.0L V10     234      German Grand Prix
# ...          ...                   ...     ...                    ...
# 551737      2023  1.6L V6 Turbo Hybrid    1107    Austrian Grand Prix
# 551738      2023  1.6L V6 Turbo Hybrid    1107    Austrian Grand Prix
# 551739      2023  1.6L V6 Turbo Hybrid    1107    Austrian Grand Prix
# 551740      2023  1.6L V6 Turbo Hybrid    1107    Austrian Grand Prix
# 551741      2023  1.6L V6 Turbo Hybrid    1108     British Grand Prix
#
#         driverId  lap_number  position                   time  \
# 0             30           1         4 0 days 00:01:45.188000
# 1             14          20         7 0 days 00:01:49.568000
# 2             14          21         6 0 days 00:01:48.693000
# 3             14          22         6 0 days 00:01:48.228000
# 4             14          23         4 0 days 00:01:47.907000
# ...          ...         ...       ...                    ...
# 551737       855          31        14 0 days 00:01:11.779000
# 551738       855          32        14 0 days 00:01:11.643000
# 551739       855          33        14 0 days 00:01:11.503000
# 551740       855          35        14 0 days 00:01:11.641000
# 551741       825          31        14 0 days 00:01:33.464000
#
#         time_milliseconds           driverRef  constructorId  \
# 0                  105188  michael_schumacher              6
# 1                  109568           coulthard              1
# 2                  108693           coulthard              1
# 3                  108228           coulthard              1
# 4                  107907           coulthard              1
# ...                   ...                 ...            ...
# 551737              71779                zhou             51
# 551738              71643                zhou             51
# 551739              71503                zhou             51
# 551740              71641                zhou             51
# 551741              93464     kevin_magnussen            210
#
#                driver_name
# 0       Michael Schumacher
# 1          David Coulthard
# 2          David Coulthard
# 3          David Coulthard
# 4          David Coulthard
# ...                    ...
# 551737         Guanyu Zhou
# 551738         Guanyu Zhou
# 551739         Guanyu Zhou
# 551740         Guanyu Zhou
# 551741     Kevin Magnussen
#
# [551742 rows x 12 columns]

# %%
duplicate_row = temp[temp.duplicated(subset=['raceId', 'driverId', 'lap_number'])]

# If there are any duplicate rows, print them
if len(duplicate_row) > 0:
    print("There are duplicate rows in the merged DataFrame:")
    duplicate_row
else:
    print("There are no duplicate rows in the merged DataFrame.")
# Out:
# There are no duplicate rows in the merged DataFrame.

# %%
duplicate_row
# Out:
# Empty DataFrame
# Columns: [seasonId, engine, raceId, name, driverId, lap_number, position, time, time_milliseconds, driverRef, constructorId, driver_name]
# Index: []

# %%
temp = temp.reindex(columns=['seasonId', 'raceId', 'name', 'driverId', 'driverRef', 'driver_name', 'constructorId', 'lap_number', 'position', 'time', 'time_milliseconds'])

# %%
temp.sort_values(by='seasonId')
# Out:
#         seasonId  raceId                   name  driverId           driverRef  \
# 0           1996     224  Australian Grand Prix        30  michael_schumacher
# 9614        1996     224  Australian Grand Prix        30  michael_schumacher
# 9615        1996     224  Australian Grand Prix        30  michael_schumacher
# 9616        1996     224  Australian Grand Prix        30  michael_schumacher
# 9617        1996     224  Australian Grand Prix        30  michael_schumacher
# ...          ...     ...                    ...       ...                 ...
# 542664      2023    1105     Spanish Grand Prix       855                zhou
# 542665      2023    1108     British Grand Prix       825     kevin_magnussen
# 542666      2023    1108     British Grand Prix       825     kevin_magnussen
# 542668      2023    1108     British Grand Prix       825     kevin_magnussen
# 551741      2023    1108     British Grand Prix       825     kevin_magnussen
#
#                driver_name  constructorId  lap_number  position  \
# 0       Michael Schumacher              6           1         4
# 9614    Michael Schumacher              6           3         3
# 9615    Michael Schumacher              6           4         3
# 9616    Michael Schumacher              6           5         3
# 9617    Michael Schumacher              6           6         3
# ...                    ...            ...         ...       ...
# 542664         Guanyu Zhou             51          37        15
# 542665     Kevin Magnussen            210          20        17
# 542666     Kevin Magnussen            210           7        20
# 542668     Kevin Magnussen            210           5        20
# 551741     Kevin Magnussen            210          31        14
#
#                          time  time_milliseconds
# 0      0 days 00:01:45.188000             105188
# 9614   0 days 00:01:35.759000              95759
# 9615   0 days 00:01:35.467000              95467
# 9616   0 days 00:01:35.254000              95254
# 9617   0 days 00:01:35.117000              95117
# ...                       ...                ...
# 542664 0 days 00:01:39.856000              99856
# 542665 0 days 00:01:33.935000              93935
# 542666 0 days 00:01:34.950000              94950
# 542668 0 days 00:01:34.598000              94598
# 551741 0 days 00:01:33.464000              93464
#
# [551742 rows x 11 columns]

# %% [markdown]
# # 5. Fact table

# %% [markdown]
# To be able to get some useful information from our dimensions, first we need to get what we need, as you know our grain is the performance of each constructor on each race between 2006 and 2021. So to get the performance data, we need to get a dataframe that contains all of these information and we are going to use the raceLapDimension

# %%
Fact = temp.loc[:, ['seasonId', 'raceId', 'constructorId']]
Fact.drop_duplicates(inplace=True)
Fact
# Out:
#         seasonId  raceId  constructorId
# 0           1996     224              6
# 1           1996     234              1
# 56          1996     234             27
# 113         1996     234              3
# 141         1996     234             22
# ...          ...     ...            ...
# 550306      2023    1107              3
# 550519      2023    1107              9
# 550679      2023    1107              6
# 550892      2023    1107            213
# 550918      2023    1107             51
#
# [5381 rows x 3 columns]

# %% [markdown]
# ## Let's build the Facts

# %% [markdown]
# We group our temporary df by constructor and by race since that's the grain of our Fact table

# %%
grouped = temp.groupby(['raceId', 'constructorId'])

# %% [markdown]
# ### Fastest laptime

# %%
fastest_laptime = grouped['time'].min()
fastest_laptime
# Out:
# raceId  constructorId
# 1       1               0 days 00:01:29.020000
#         2               0 days 00:01:27.988000
#         3               0 days 00:01:27.706000
#         4               0 days 00:01:28.712000
#         5               0 days 00:01:29.230000
#                                  ...
# 1110    117             0 days 00:01:50.938000
#         131             0 days 00:01:47.305000
#         210             0 days 00:01:49.907000
#         213             0 days 00:01:50.994000
#         214             0 days 00:01:50.439000
# Name: time, Length: 5381, dtype: timedelta64[ns]

# %%
Fact = Fact.merge(fastest_laptime, on=['raceId', 'constructorId'], how='left')
Fact.rename(columns={'time': 'fastest_laptime'}, inplace=True)
Fact
# Out:
#       seasonId  raceId  constructorId        fastest_laptime
# 0         1996     224              6 0 days 00:01:33.651000
# 1         1996     234              1 0 days 00:01:47.856000
# 2         1996     234             27 0 days 00:01:48.288000
# 3         1996     234              3 0 days 00:01:46.504000
# 4         1996     234             22 0 days 00:01:47.643000
# ...        ...     ...            ...                    ...
# 5376      2023    1107              3 0 days 00:01:09.560000
# 5377      2023    1107              9 0 days 00:01:07.012000
# 5378      2023    1107              6 0 days 00:01:08.820000
# 5379      2023    1107            213 0 days 00:01:09.620000
# 5380      2023    1107             51 0 days 00:01:09.786000
#
# [5381 rows x 4 columns]

# %% [markdown]
# ### Average laptime

# %%
avg_laptime = grouped['time'].mean()
avg_laptime
# Out:
# raceId  constructorId
# 1       1               0 days 00:01:37.563758620
#         2               0 days 00:01:36.431035398
#         3               0 days 00:01:36.299786666
#         4               0 days 00:01:38.817524390
#         5               0 days 00:01:37.619568965
#                                    ...
# 1110    117             0 days 00:01:54.050272727
#         131             0 days 00:01:53.791727272
#         210             0 days 00:01:54.921636363
#         213             0 days 00:01:54.593090909
#         214             0 days 00:01:54.303443181
# Name: time, Length: 5381, dtype: timedelta64[ns]

# %%
Fact = Fact.merge(avg_laptime, on=['raceId', 'constructorId'], how='left')
Fact.rename(columns={'time': 'avg_laptime'}, inplace=True)
Fact
# Out:
#       seasonId  raceId  constructorId        fastest_laptime  \
# 0         1996     224              6 0 days 00:01:33.651000
# 1         1996     234              1 0 days 00:01:47.856000
# 2         1996     234             27 0 days 00:01:48.288000
# 3         1996     234              3 0 days 00:01:46.504000
# 4         1996     234             22 0 days 00:01:47.643000
# ...        ...     ...            ...                    ...
# 5376      2023    1107              3 0 days 00:01:09.560000
# 5377      2023    1107              9 0 days 00:01:07.012000
# 5378      2023    1107              6 0 days 00:01:08.820000
# 5379      2023    1107            213 0 days 00:01:09.620000
# 5380      2023    1107             51 0 days 00:01:09.786000
#
#                    avg_laptime
# 0    0 days 00:01:37.941433333
# 1    0 days 00:01:49.922568965
# 2    0 days 00:01:51.177171875
# 3    0 days 00:01:49.341777777
# 4    0 days 00:01:49.099793103
# ...                        ...
# 5376 0 days 00:01:13.428120567
# 5377 0 days 00:01:12.425366197
# 5378 0 days 00:01:12.491169014
# 5379 0 days 00:01:13.869928571
# 5380 0 days 00:01:13.818742857
#
# [5381 rows x 5 columns]

# %% [markdown]
# ### Average laptime in milliseconds

# %%
avg_laptime_milliseconds = grouped['time_milliseconds'].mean().round(3)
avg_laptime_milliseconds
# Out:
# raceId  constructorId
# 1       1                 97563.759
#         2                 96431.035
#         3                 96299.787
#         4                 98817.524
#         5                 97619.569
#                             ...
# 1110    117              114050.273
#         131              113791.727
#         210              114921.636
#         213              114593.091
#         214              114303.443
# Name: time_milliseconds, Length: 5381, dtype: float64

# %%
Fact = Fact.merge(avg_laptime_milliseconds, on=['raceId', 'constructorId'], how='left')
Fact.rename(columns={'time_milliseconds': 'avg_laptime_milliseconds'}, inplace=True)
Fact
# Out:
#       seasonId  raceId  constructorId        fastest_laptime  \
# 0         1996     224              6 0 days 00:01:33.651000
# 1         1996     234              1 0 days 00:01:47.856000
# 2         1996     234             27 0 days 00:01:48.288000
# 3         1996     234              3 0 days 00:01:46.504000
# 4         1996     234             22 0 days 00:01:47.643000
# ...        ...     ...            ...                    ...
# 5376      2023    1107              3 0 days 00:01:09.560000
# 5377      2023    1107              9 0 days 00:01:07.012000
# 5378      2023    1107              6 0 days 00:01:08.820000
# 5379      2023    1107            213 0 days 00:01:09.620000
# 5380      2023    1107             51 0 days 00:01:09.786000
#
#                    avg_laptime  avg_laptime_milliseconds
# 0    0 days 00:01:37.941433333                 97941.433
# 1    0 days 00:01:49.922568965                109922.569
# 2    0 days 00:01:51.177171875                111177.172
# 3    0 days 00:01:49.341777777                109341.778
# 4    0 days 00:01:49.099793103                109099.793
# ...                        ...                       ...
# 5376 0 days 00:01:13.428120567                 73428.121
# 5377 0 days 00:01:12.425366197                 72425.366
# 5378 0 days 00:01:12.491169014                 72491.169
# 5379 0 days 00:01:13.869928571                 73869.929
# 5380 0 days 00:01:13.818742857                 73818.743
#
# [5381 rows x 6 columns]

# %% [markdown]
# ### Slowest laptime

# %%
slowest_laptime = grouped['time'].max()
slowest_laptime
# Out:
# raceId  constructorId
# 1       1               0 days 00:02:33.309000
#         2               0 days 00:02:37.754000
#         3               0 days 00:02:35.699000
#         4               0 days 00:02:35.582000
#         5               0 days 00:02:35.605000
#                                  ...
# 1110    117             0 days 00:02:13.650000
#         131             0 days 00:02:09.564000
#         210             0 days 00:02:07.746000
#         213             0 days 00:02:09.835000
#         214             0 days 00:02:09.405000
# Name: time, Length: 5381, dtype: timedelta64[ns]

# %%
Fact = Fact.merge(slowest_laptime, on=['raceId', 'constructorId'], how='left')
Fact.rename(columns={'time': 'slowest_laptime'}, inplace=True)
Fact
# Out:
#       seasonId  raceId  constructorId        fastest_laptime  \
# 0         1996     224              6 0 days 00:01:33.651000
# 1         1996     234              1 0 days 00:01:47.856000
# 2         1996     234             27 0 days 00:01:48.288000
# 3         1996     234              3 0 days 00:01:46.504000
# 4         1996     234             22 0 days 00:01:47.643000
# ...        ...     ...            ...                    ...
# 5376      2023    1107              3 0 days 00:01:09.560000
# 5377      2023    1107              9 0 days 00:01:07.012000
# 5378      2023    1107              6 0 days 00:01:08.820000
# 5379      2023    1107            213 0 days 00:01:09.620000
# 5380      2023    1107             51 0 days 00:01:09.786000
#
#                    avg_laptime  avg_laptime_milliseconds  \
# 0    0 days 00:01:37.941433333                 97941.433
# 1    0 days 00:01:49.922568965                109922.569
# 2    0 days 00:01:51.177171875                111177.172
# 3    0 days 00:01:49.341777777                109341.778
# 4    0 days 00:01:49.099793103                109099.793
# ...                        ...                       ...
# 5376 0 days 00:01:13.428120567                 73428.121
# 5377 0 days 00:01:12.425366197                 72425.366
# 5378 0 days 00:01:12.491169014                 72491.169
# 5379 0 days 00:01:13.869928571                 73869.929
# 5380 0 days 00:01:13.818742857                 73818.743
#
#             slowest_laptime
# 0    0 days 00:03:02.162000
# 1    0 days 00:02:05.234000
# 2    0 days 00:02:11.795000
# 3    0 days 00:02:10.504000
# 4    0 days 00:02:09.427000
# ...                     ...
# 5376 0 days 00:01:59.986000
# 5377 0 days 00:02:04.721000
# 5378 0 days 00:02:03.609000
# 5379 0 days 00:02:02.360000
# 5380 0 days 00:02:00.550000
#
# [5381 rows x 7 columns]

# %% [markdown]
# ### Slowest laptime in milliseconds

# %%
slowest_laptime_milliseconds = grouped['time_milliseconds'].max()
slowest_laptime_milliseconds
# Out:
# raceId  constructorId
# 1       1                153309
#         2                157754
#         3                155699
#         4                155582
#         5                155605
#                           ...
# 1110    117              133650
#         131              129564
#         210              127746
#         213              129835
#         214              129405
# Name: time_milliseconds, Length: 5381, dtype: int64

# %%
Fact = Fact.merge(slowest_laptime_milliseconds, on=['raceId', 'constructorId'], how='left')
Fact.rename(columns={'time_milliseconds': 'slowest_laptime_milliseconds'}, inplace=True)
Fact
# Out:
#       seasonId  raceId  constructorId        fastest_laptime  \
# 0         1996     224              6 0 days 00:01:33.651000
# 1         1996     234              1 0 days 00:01:47.856000
# 2         1996     234             27 0 days 00:01:48.288000
# 3         1996     234              3 0 days 00:01:46.504000
# 4         1996     234             22 0 days 00:01:47.643000
# ...        ...     ...            ...                    ...
# 5376      2023    1107              3 0 days 00:01:09.560000
# 5377      2023    1107              9 0 days 00:01:07.012000
# 5378      2023    1107              6 0 days 00:01:08.820000
# 5379      2023    1107            213 0 days 00:01:09.620000
# 5380      2023    1107             51 0 days 00:01:09.786000
#
#                    avg_laptime  avg_laptime_milliseconds  \
# 0    0 days 00:01:37.941433333                 97941.433
# 1    0 days 00:01:49.922568965                109922.569
# 2    0 days 00:01:51.177171875                111177.172
# 3    0 days 00:01:49.341777777                109341.778
# 4    0 days 00:01:49.099793103                109099.793
# ...                        ...                       ...
# 5376 0 days 00:01:13.428120567                 73428.121
# 5377 0 days 00:01:12.425366197                 72425.366
# 5378 0 days 00:01:12.491169014                 72491.169
# 5379 0 days 00:01:13.869928571                 73869.929
# 5380 0 days 00:01:13.818742857                 73818.743
#
#             slowest_laptime  slowest_laptime_milliseconds
# 0    0 days 00:03:02.162000                        182162
# 1    0 days 00:02:05.234000                        125234
# 2    0 days 00:02:11.795000                        131795
# 3    0 days 00:02:10.504000                        130504
# 4    0 days 00:02:09.427000                        129427
# ...                     ...                           ...
# 5376 0 days 00:01:59.986000                        119986
# 5377 0 days 00:02:04.721000                        124721
# 5378 0 days 00:02:03.609000                        123609
# 5379 0 days 00:02:02.360000                        122360
# 5380 0 days 00:02:00.550000                        120550
#
# [5381 rows x 8 columns]

# %% [markdown]
# ### Fastest laptime in milliseconds

# %%
fastest_laptime_milliseconds = grouped['time_milliseconds'].min()
fastest_laptime_milliseconds
# Out:
# raceId  constructorId
# 1       1                 89020
#         2                 87988
#         3                 87706
#         4                 88712
#         5                 89230
#                           ...
# 1110    117              110938
#         131              107305
#         210              109907
#         213              110994
#         214              110439
# Name: time_milliseconds, Length: 5381, dtype: int64

# %%
Fact = Fact.merge(fastest_laptime_milliseconds, on=['raceId', 'constructorId'], how='left')
Fact.rename(columns={'time_milliseconds': 'fastest_laptime_milliseconds'}, inplace=True)
Fact
# Out:
#       seasonId  raceId  constructorId        fastest_laptime  \
# 0         1996     224              6 0 days 00:01:33.651000
# 1         1996     234              1 0 days 00:01:47.856000
# 2         1996     234             27 0 days 00:01:48.288000
# 3         1996     234              3 0 days 00:01:46.504000
# 4         1996     234             22 0 days 00:01:47.643000
# ...        ...     ...            ...                    ...
# 5376      2023    1107              3 0 days 00:01:09.560000
# 5377      2023    1107              9 0 days 00:01:07.012000
# 5378      2023    1107              6 0 days 00:01:08.820000
# 5379      2023    1107            213 0 days 00:01:09.620000
# 5380      2023    1107             51 0 days 00:01:09.786000
#
#                    avg_laptime  avg_laptime_milliseconds  \
# 0    0 days 00:01:37.941433333                 97941.433
# 1    0 days 00:01:49.922568965                109922.569
# 2    0 days 00:01:51.177171875                111177.172
# 3    0 days 00:01:49.341777777                109341.778
# 4    0 days 00:01:49.099793103                109099.793
# ...                        ...                       ...
# 5376 0 days 00:01:13.428120567                 73428.121
# 5377 0 days 00:01:12.425366197                 72425.366
# 5378 0 days 00:01:12.491169014                 72491.169
# 5379 0 days 00:01:13.869928571                 73869.929
# 5380 0 days 00:01:13.818742857                 73818.743
#
#             slowest_laptime  slowest_laptime_milliseconds  \
# 0    0 days 00:03:02.162000                        182162
# 1    0 days 00:02:05.234000                        125234
# 2    0 days 00:02:11.795000                        131795
# 3    0 days 00:02:10.504000                        130504
# 4    0 days 00:02:09.427000                        129427
# ...                     ...                           ...
# 5376 0 days 00:01:59.986000                        119986
# 5377 0 days 00:02:04.721000                        124721
# 5378 0 days 00:02:03.609000                        123609
# 5379 0 days 00:02:02.360000                        122360
# 5380 0 days 00:02:00.550000                        120550
#
#       fastest_laptime_milliseconds
# 0                            93651
# 1                           107856
# 2                           108288
# 3                           106504
# 4                           107643
# ...                            ...
# 5376                         69560
# 5377                         67012
# 5378                         68820
# 5379                         69620
# 5380                         69786
#
# [5381 rows x 9 columns]

# %% [markdown]
# ### Best position during the race

# %%
best_racePosition = grouped['position'].min()
best_racePosition
# Out:
# raceId  constructorId
# 1       1                3
#         2                3
#         3                3
#         4                3
#         5                4
#                         ..
# 1110    117              4
#         131              3
#         210              8
#         213              6
#         214              6
# Name: position, Length: 5381, dtype: int64

# %%
Fact = Fact.merge(best_racePosition, on=['raceId', 'constructorId'], how='left')
Fact.rename(columns={'position': 'best_racePosition'}, inplace=True)
Fact
# Out:
#       seasonId  raceId  constructorId        fastest_laptime  \
# 0         1996     224              6 0 days 00:01:33.651000
# 1         1996     234              1 0 days 00:01:47.856000
# 2         1996     234             27 0 days 00:01:48.288000
# 3         1996     234              3 0 days 00:01:46.504000
# 4         1996     234             22 0 days 00:01:47.643000
# ...        ...     ...            ...                    ...
# 5376      2023    1107              3 0 days 00:01:09.560000
# 5377      2023    1107              9 0 days 00:01:07.012000
# 5378      2023    1107              6 0 days 00:01:08.820000
# 5379      2023    1107            213 0 days 00:01:09.620000
# 5380      2023    1107             51 0 days 00:01:09.786000
#
#                    avg_laptime  avg_laptime_milliseconds  \
# 0    0 days 00:01:37.941433333                 97941.433
# 1    0 days 00:01:49.922568965                109922.569
# 2    0 days 00:01:51.177171875                111177.172
# 3    0 days 00:01:49.341777777                109341.778
# 4    0 days 00:01:49.099793103                109099.793
# ...                        ...                       ...
# 5376 0 days 00:01:13.428120567                 73428.121
# 5377 0 days 00:01:12.425366197                 72425.366
# 5378 0 days 00:01:12.491169014                 72491.169
# 5379 0 days 00:01:13.869928571                 73869.929
# 5380 0 days 00:01:13.818742857                 73818.743
#
#             slowest_laptime  slowest_laptime_milliseconds  \
# 0    0 days 00:03:02.162000                        182162
# 1    0 days 00:02:05.234000                        125234
# 2    0 days 00:02:11.795000                        131795
# 3    0 days 00:02:10.504000                        130504
# 4    0 days 00:02:09.427000                        129427
# ...                     ...                           ...
# 5376 0 days 00:01:59.986000                        119986
# 5377 0 days 00:02:04.721000                        124721
# 5378 0 days 00:02:03.609000                        123609
# 5379 0 days 00:02:02.360000                        122360
# 5380 0 days 00:02:00.550000                        120550
#
#       fastest_laptime_milliseconds  best_racePosition
# 0                            93651                  3
# 1                           107856                  4
# 2                           108288                  7
# 3                           106504                  1
# 4                           107643                  1
# ...                            ...                ...
# 5376                         69560                  9
# 5377                         67012                  1
# 5378                         68820                  1
# 5379                         69620                  8
# 5380                         69786                 10
#
# [5381 rows x 10 columns]

# %% [markdown]
# ### Average position during the race

# %%
avg_racePosition = grouped['position'].mean().round(2)
avg_racePosition
# Out:
# raceId  constructorId
# 1       1                 9.67
#         2                10.19
#         3                 6.60
#         4                 8.96
#         5                11.42
#                          ...
# 1110    117               6.99
#         131               5.55
#         210              14.19
#         213              12.14
#         214              10.52
# Name: position, Length: 5381, dtype: float64

# %%
Fact = Fact.merge(avg_racePosition, on=['raceId', 'constructorId'], how='left')
Fact.rename(columns={'position': 'avg_racePosition'}, inplace=True)
Fact
# Out:
#       seasonId  raceId  constructorId        fastest_laptime  \
# 0         1996     224              6 0 days 00:01:33.651000
# 1         1996     234              1 0 days 00:01:47.856000
# 2         1996     234             27 0 days 00:01:48.288000
# 3         1996     234              3 0 days 00:01:46.504000
# 4         1996     234             22 0 days 00:01:47.643000
# ...        ...     ...            ...                    ...
# 5376      2023    1107              3 0 days 00:01:09.560000
# 5377      2023    1107              9 0 days 00:01:07.012000
# 5378      2023    1107              6 0 days 00:01:08.820000
# 5379      2023    1107            213 0 days 00:01:09.620000
# 5380      2023    1107             51 0 days 00:01:09.786000
#
#                    avg_laptime  avg_laptime_milliseconds  \
# 0    0 days 00:01:37.941433333                 97941.433
# 1    0 days 00:01:49.922568965                109922.569
# 2    0 days 00:01:51.177171875                111177.172
# 3    0 days 00:01:49.341777777                109341.778
# 4    0 days 00:01:49.099793103                109099.793
# ...                        ...                       ...
# 5376 0 days 00:01:13.428120567                 73428.121
# 5377 0 days 00:01:12.425366197                 72425.366
# 5378 0 days 00:01:12.491169014                 72491.169
# 5379 0 days 00:01:13.869928571                 73869.929
# 5380 0 days 00:01:13.818742857                 73818.743
#
#             slowest_laptime  slowest_laptime_milliseconds  \
# 0    0 days 00:03:02.162000                        182162
# 1    0 days 00:02:05.234000                        125234
# 2    0 days 00:02:11.795000                        131795
# 3    0 days 00:02:10.504000                        130504
# 4    0 days 00:02:09.427000                        129427
# ...                     ...                           ...
# 5376 0 days 00:01:59.986000                        119986
# 5377 0 days 00:02:04.721000                        124721
# 5378 0 days 00:02:03.609000                        123609
# 5379 0 days 00:02:02.360000                        122360
# 5380 0 days 00:02:00.550000                        120550
#
#       fastest_laptime_milliseconds  best_racePosition  avg_racePosition
# 0                            93651                  3              3.56
# 1                           107856                  4              5.88
# 2                           108288                  7             11.16
# 3                           106504                  1              3.59
# 4                           107643                  1              1.87
# ...                            ...                ...               ...
# 5376                         69560                  9             12.12
# 5377                         67012                  1              3.63
# 5378                         68820                  1              2.61
# 5379                         69620                  8             16.31
# 5380                         69786                 10             16.00
#
# [5381 rows x 11 columns]

# %% [markdown]
# ### Worst race position

# %%
worst_racePosition = grouped['position'].max()
worst_racePosition
# Out:
# raceId  constructorId
# 1       1                15
#         2                17
#         3                13
#         4                15
#         5                16
#                          ..
# 1110    117              18
#         131              15
#         210              19
#         213              19
#         214              17
# Name: position, Length: 5381, dtype: int64

# %%
Fact = Fact.merge(worst_racePosition, on=['raceId', 'constructorId'], how='left')
Fact.rename(columns={'position': 'worst_racePosition'}, inplace=True)
Fact
# Out:
#       seasonId  raceId  constructorId        fastest_laptime  \
# 0         1996     224              6 0 days 00:01:33.651000
# 1         1996     234              1 0 days 00:01:47.856000
# 2         1996     234             27 0 days 00:01:48.288000
# 3         1996     234              3 0 days 00:01:46.504000
# 4         1996     234             22 0 days 00:01:47.643000
# ...        ...     ...            ...                    ...
# 5376      2023    1107              3 0 days 00:01:09.560000
# 5377      2023    1107              9 0 days 00:01:07.012000
# 5378      2023    1107              6 0 days 00:01:08.820000
# 5379      2023    1107            213 0 days 00:01:09.620000
# 5380      2023    1107             51 0 days 00:01:09.786000
#
#                    avg_laptime  avg_laptime_milliseconds  \
# 0    0 days 00:01:37.941433333                 97941.433
# 1    0 days 00:01:49.922568965                109922.569
# 2    0 days 00:01:51.177171875                111177.172
# 3    0 days 00:01:49.341777777                109341.778
# 4    0 days 00:01:49.099793103                109099.793
# ...                        ...                       ...
# 5376 0 days 00:01:13.428120567                 73428.121
# 5377 0 days 00:01:12.425366197                 72425.366
# 5378 0 days 00:01:12.491169014                 72491.169
# 5379 0 days 00:01:13.869928571                 73869.929
# 5380 0 days 00:01:13.818742857                 73818.743
#
#             slowest_laptime  slowest_laptime_milliseconds  \
# 0    0 days 00:03:02.162000                        182162
# 1    0 days 00:02:05.234000                        125234
# 2    0 days 00:02:11.795000                        131795
# 3    0 days 00:02:10.504000                        130504
# 4    0 days 00:02:09.427000                        129427
# ...                     ...                           ...
# 5376 0 days 00:01:59.986000                        119986
# 5377 0 days 00:02:04.721000                        124721
# 5378 0 days 00:02:03.609000                        123609
# 5379 0 days 00:02:02.360000                        122360
# 5380 0 days 00:02:00.550000                        120550
#
#       fastest_laptime_milliseconds  best_racePosition  avg_racePosition  \
# 0                            93651                  3              3.56
# 1                           107856                  4              5.88
# 2                           108288                  7             11.16
# 3                           106504                  1              3.59
# 4                           107643                  1              1.87
# ...                            ...                ...               ...
# 5376                         69560                  9             12.12
# 5377                         67012                  1              3.63
# 5378                         68820                  1              2.61
# 5379                         69620                  8             16.31
# 5380                         69786                 10             16.00
#
#       worst_racePosition
# 0                      9
# 1                      8
# 2                     18
# 3                      6
# 4                      3
# ...                  ...
# 5376                  17
# 5377                  14
# 5378                   6
# 5379                  20
# 5380                  20
#
# [5381 rows x 12 columns]

# %% [markdown]
# ### Fastest lap speed

# %%
results
# Out:
#        resultId  raceId  driverId  constructorId number  grid position  \
# 0             1      18         1              1     22     1        1
# 1             2      18         2              2      3     5        2
# 2             3      18         3              3      7     7        3
# 3             4      18         4              4      5    11        4
# 4             5      18         5              1     23     3        5
# ...         ...     ...       ...            ...    ...   ...      ...
# 26075     26081    1110       817            213      3    19       16
# 26076     26082    1110       858              3      2    18       17
# 26077     26083    1110       807            210     27     0       18
# 26078     26084    1110       832              6     55     4       \N
# 26079     26085    1110       857              1     81     5       \N
#
#       positionText  positionOrder  points  laps         time milliseconds  \
# 0                1              1    10.0    58  1:34:50.616      5690616
# 1                2              2     8.0    58       +5.478      5696094
# 2                3              3     6.0    58       +8.163      5698779
# 3                4              4     5.0    58      +17.181      5707797
# 4                5              5     4.0    58      +18.014      5708630
# ...            ...            ...     ...   ...          ...          ...
# 26075           16             16     0.0    44    +1:43.071      5053521
# 26076           17             17     0.0    44    +1:44.476      5054926
# 26077           18             18     0.0    44    +1:50.450      5060900
# 26078            R             19     0.0    23           \N           \N
# 26079            R             20     0.0     0           \N           \N
#
#       fastestLap rank fastestLapTime fastestLapSpeed  statusId
# 0             39    2       1:27.452         218.300         1
# 1             41    3       1:27.739         217.586         1
# 2             41    5       1:28.090         216.719         1
# 3             58    7       1:28.603         215.464         1
# 4             43    1       1:27.418         218.385         1
# ...          ...  ...            ...             ...       ...
# 26075         25   15       1:50.994         227.169         1
# 26076         37    9       1:50.486         228.213         1
# 26077         26    4       1:49.907         229.415         1
# 26078          9   19       1:53.138         222.864       130
# 26079         \N    0             \N              \N       130
#
# [26080 rows x 18 columns]

# %%
enrich = pd.merge(Fact, results[['raceId', 'constructorId', 'fastestLapSpeed']],
                     on=['raceId', 'constructorId'], how='inner')
enrich
# Out:
#        seasonId  raceId  constructorId        fastest_laptime  \
# 0          1996     224              6 0 days 00:01:33.651000
# 1          1996     224              6 0 days 00:01:33.651000
# 2          1996     234              1 0 days 00:01:47.856000
# 3          1996     234              1 0 days 00:01:47.856000
# 4          1996     234             27 0 days 00:01:48.288000
# ...         ...     ...            ...                    ...
# 10750      2023    1107              6 0 days 00:01:08.820000
# 10751      2023    1107            213 0 days 00:01:09.620000
# 10752      2023    1107            213 0 days 00:01:09.620000
# 10753      2023    1107             51 0 days 00:01:09.786000
# 10754      2023    1107             51 0 days 00:01:09.786000
#
#                     avg_laptime  avg_laptime_milliseconds  \
# 0     0 days 00:01:37.941433333                 97941.433
# 1     0 days 00:01:37.941433333                 97941.433
# 2     0 days 00:01:49.922568965                109922.569
# 3     0 days 00:01:49.922568965                109922.569
# 4     0 days 00:01:51.177171875                111177.172
# ...                         ...                       ...
# 10750 0 days 00:01:12.491169014                 72491.169
# 10751 0 days 00:01:13.869928571                 73869.929
# 10752 0 days 00:01:13.869928571                 73869.929
# 10753 0 days 00:01:13.818742857                 73818.743
# 10754 0 days 00:01:13.818742857                 73818.743
#
#              slowest_laptime  slowest_laptime_milliseconds  \
# 0     0 days 00:03:02.162000                        182162
# 1     0 days 00:03:02.162000                        182162
# 2     0 days 00:02:05.234000                        125234
# 3     0 days 00:02:05.234000                        125234
# 4     0 days 00:02:11.795000                        131795
# ...                      ...                           ...
# 10750 0 days 00:02:03.609000                        123609
# 10751 0 days 00:02:02.360000                        122360
# 10752 0 days 00:02:02.360000                        122360
# 10753 0 days 00:02:00.550000                        120550
# 10754 0 days 00:02:00.550000                        120550
#
#        fastest_laptime_milliseconds  best_racePosition  avg_racePosition  \
# 0                             93651                  3              3.56
# 1                             93651                  3              3.56
# 2                            107856                  4              5.88
# 3                            107856                  4              5.88
# 4                            108288                  7             11.16
# ...                             ...                ...               ...
# 10750                         68820                  1              2.61
# 10751                         69620                  8             16.31
# 10752                         69620                  8             16.31
# 10753                         69786                 10             16.00
# 10754                         69786                 10             16.00
#
#        worst_racePosition fastestLapSpeed
# 0                       9              \N
# 1                       9              \N
# 2                       8              \N
# 3                       8              \N
# 4                      18              \N
# ...                   ...             ...
# 10750                   6         224.934
# 10751                  20         222.507
# 10752                  20         221.511
# 10753                  20         222.714
# 10754                  20         222.539
#
# [10755 rows x 13 columns]

# %% [markdown]
# Remove duplicates and keep the best because each constructor has 2 drivers

# %%
performance_fact = enrich.loc[enrich.groupby(['seasonId', 'raceId', 'constructorId'])['fastestLapSpeed'].idxmax()]
performance_fact
# Out:
#        seasonId  raceId  constructorId        fastest_laptime  \
# 226        1996     224              1 0 days 00:01:35.843000
# 224        1996     224              3 0 days 00:01:33.421000
# 0          1996     224              6 0 days 00:01:33.651000
# 214        1996     224             15 0 days 00:01:35.596000
# 212        1996     224             17 0 days 00:01:35.064000
# ...         ...     ...            ...                    ...
# 10703      2023    1110            117 0 days 00:01:50.938000
# 10691      2023    1110            131 0 days 00:01:47.305000
# 10696      2023    1110            210 0 days 00:01:49.907000
# 10694      2023    1110            213 0 days 00:01:50.994000
# 10687      2023    1110            214 0 days 00:01:50.439000
#
#                     avg_laptime  avg_laptime_milliseconds  \
# 226   0 days 00:01:38.301304878                 98301.305
# 224   0 days 00:01:36.370706896                 96370.707
# 0     0 days 00:01:37.941433333                 97941.433
# 214   0 days 00:01:38.411157894                 98411.158
# 212   0 days 00:01:38.729766666                 98729.767
# ...                         ...                       ...
# 10703 0 days 00:01:54.050272727                114050.273
# 10691 0 days 00:01:53.791727272                113791.727
# 10696 0 days 00:01:54.921636363                114921.636
# 10694 0 days 00:01:54.593090909                114593.091
# 10687 0 days 00:01:54.303443181                114303.443
#
#              slowest_laptime  slowest_laptime_milliseconds  \
# 226   0 days 00:02:06.391000                        126391
# 224   0 days 00:02:09.739000                        129739
# 0     0 days 00:03:02.162000                        182162
# 214   0 days 00:02:12.864000                        132864
# 212   0 days 00:02:03.021000                        123021
# ...                      ...                           ...
# 10703 0 days 00:02:13.650000                        133650
# 10691 0 days 00:02:09.564000                        129564
# 10696 0 days 00:02:07.746000                        127746
# 10694 0 days 00:02:09.835000                        129835
# 10687 0 days 00:02:09.405000                        129405
#
#        fastest_laptime_milliseconds  best_racePosition  avg_racePosition  \
# 226                           95843                  4              7.94
# 224                           93421                  1              1.50
# 0                             93651                  3              3.56
# 214                           95596                  6              8.54
# 212                           95064                  5              6.73
# ...                             ...                ...               ...
# 10703                        110938                  4              6.99
# 10691                        107305                  3              5.55
# 10696                        109907                  8             14.19
# 10694                        110994                  6             12.14
# 10687                        110439                  6             10.52
#
#        worst_racePosition fastestLapSpeed
# 226                    19              \N
# 224                     2              \N
# 0                       9              \N
# 214                    11              \N
# 212                    18              \N
# ...                   ...             ...
# 10703                  18         227.283
# 10691                  15         234.978
# 10696                  19         229.415
# 10694                  19         227.169
# 10687                  17         228.310
#
# [5381 rows x 13 columns]

# %%
null_count2 = (performance_fact['fastestLapSpeed'] == '\\N').sum()
print("Number of null values in the fastestLapSpeed:", null_count2)
# Out:
# Number of null values in the fastestLapSpeed: 1719

# %% [markdown]
# reduce value noise : avg_racePosition, avp_laptimemilliseconds

# %%
performance_fact.replace('\\N', pd.NA, inplace=True)
performance_fact['fastestLapSpeed'].fillna(0,inplace=True)
performance_fact['fastestLapSpeed'] = performance_fact['fastestLapSpeed'].astype(float)
performance_fact
# Out:
# <ipython-input-79-1e3d8291dc40>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   performance_fact['fastestLapSpeed'].fillna(0,inplace=True)
#        seasonId  raceId  constructorId        fastest_laptime  \
# 226        1996     224              1 0 days 00:01:35.843000
# 224        1996     224              3 0 days 00:01:33.421000
# 0          1996     224              6 0 days 00:01:33.651000
# 214        1996     224             15 0 days 00:01:35.596000
# 212        1996     224             17 0 days 00:01:35.064000
# ...         ...     ...            ...                    ...
# 10703      2023    1110            117 0 days 00:01:50.938000
# 10691      2023    1110            131 0 days 00:01:47.305000
# 10696      2023    1110            210 0 days 00:01:49.907000
# 10694      2023    1110            213 0 days 00:01:50.994000
# 10687      2023    1110            214 0 days 00:01:50.439000
#
#                     avg_laptime  avg_laptime_milliseconds  \
# 226   0 days 00:01:38.301304878                 98301.305
# 224   0 days 00:01:36.370706896                 96370.707
# 0     0 days 00:01:37.941433333                 97941.433
# 214   0 days 00:01:38.411157894                 98411.158
# 212   0 days 00:01:38.729766666                 98729.767
# ...                         ...                       ...
# 10703 0 days 00:01:54.050272727                114050.273
# 10691 0 days 00:01:53.791727272                113791.727
# 10696 0 days 00:01:54.921636363                114921.636
# 10694 0 days 00:01:54.593090909                114593.091
# 10687 0 days 00:01:54.303443181                114303.443
#
#              slowest_laptime  slowest_laptime_milliseconds  \
# 226   0 days 00:02:06.391000                        126391
# 224   0 days 00:02:09.739000                        129739
# 0     0 days 00:03:02.162000                        182162
# 214   0 days 00:02:12.864000                        132864
# 212   0 days 00:02:03.021000                        123021
# ...                      ...                           ...
# 10703 0 days 00:02:13.650000                        133650
# 10691 0 days 00:02:09.564000                        129564
# 10696 0 days 00:02:07.746000                        127746
# 10694 0 days 00:02:09.835000                        129835
# 10687 0 days 00:02:09.405000                        129405
#
#        fastest_laptime_milliseconds  best_racePosition  avg_racePosition  \
# 226                           95843                  4              7.94
# 224                           93421                  1              1.50
# 0                             93651                  3              3.56
# 214                           95596                  6              8.54
# 212                           95064                  5              6.73
# ...                             ...                ...               ...
# 10703                        110938                  4              6.99
# 10691                        107305                  3              5.55
# 10696                        109907                  8             14.19
# 10694                        110994                  6             12.14
# 10687                        110439                  6             10.52
#
#        worst_racePosition  fastestLapSpeed
# 226                    19            0.000
# 224                     2            0.000
# 0                       9            0.000
# 214                    11            0.000
# 212                    18            0.000
# ...                   ...              ...
# 10703                  18          227.283
# 10691                  15          234.978
# 10696                  19          229.415
# 10694                  19          227.169
# 10687                  17          228.310
#
# [5381 rows x 13 columns]

# %% [markdown]
# ## PERFORMANCE FACT TABLE

# %%
performance_fact
# Out:
#        seasonId  raceId  constructorId        fastest_laptime  \
# 226        1996     224              1 0 days 00:01:35.843000
# 224        1996     224              3 0 days 00:01:33.421000
# 0          1996     224              6 0 days 00:01:33.651000
# 214        1996     224             15 0 days 00:01:35.596000
# 212        1996     224             17 0 days 00:01:35.064000
# ...         ...     ...            ...                    ...
# 10703      2023    1110            117 0 days 00:01:50.938000
# 10691      2023    1110            131 0 days 00:01:47.305000
# 10696      2023    1110            210 0 days 00:01:49.907000
# 10694      2023    1110            213 0 days 00:01:50.994000
# 10687      2023    1110            214 0 days 00:01:50.439000
#
#                     avg_laptime  avg_laptime_milliseconds  \
# 226   0 days 00:01:38.301304878                 98301.305
# 224   0 days 00:01:36.370706896                 96370.707
# 0     0 days 00:01:37.941433333                 97941.433
# 214   0 days 00:01:38.411157894                 98411.158
# 212   0 days 00:01:38.729766666                 98729.767
# ...                         ...                       ...
# 10703 0 days 00:01:54.050272727                114050.273
# 10691 0 days 00:01:53.791727272                113791.727
# 10696 0 days 00:01:54.921636363                114921.636
# 10694 0 days 00:01:54.593090909                114593.091
# 10687 0 days 00:01:54.303443181                114303.443
#
#              slowest_laptime  slowest_laptime_milliseconds  \
# 226   0 days 00:02:06.391000                        126391
# 224   0 days 00:02:09.739000                        129739
# 0     0 days 00:03:02.162000                        182162
# 214   0 days 00:02:12.864000                        132864
# 212   0 days 00:02:03.021000                        123021
# ...                      ...                           ...
# 10703 0 days 00:02:13.650000                        133650
# 10691 0 days 00:02:09.564000                        129564
# 10696 0 days 00:02:07.746000                        127746
# 10694 0 days 00:02:09.835000                        129835
# 10687 0 days 00:02:09.405000                        129405
#
#        fastest_laptime_milliseconds  best_racePosition  avg_racePosition  \
# 226                           95843                  4              7.94
# 224                           93421                  1              1.50
# 0                             93651                  3              3.56
# 214                           95596                  6              8.54
# 212                           95064                  5              6.73
# ...                             ...                ...               ...
# 10703                        110938                  4              6.99
# 10691                        107305                  3              5.55
# 10696                        109907                  8             14.19
# 10694                        110994                  6             12.14
# 10687                        110439                  6             10.52
#
#        worst_racePosition  fastestLapSpeed
# 226                    19            0.000
# 224                     2            0.000
# 0                       9            0.000
# 214                    11            0.000
# 212                    18            0.000
# ...                   ...              ...
# 10703                  18          227.283
# 10691                  15          234.978
# 10696                  19          229.415
# 10694                  19          227.169
# 10687                  17          228.310
#
# [5381 rows x 13 columns]

# %%
performance_fact.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5381 entries, 226 to 10687
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   seasonId                      5381 non-null   int64
#  1   raceId                        5381 non-null   int64
#  2   constructorId                 5381 non-null   int64
#  3   fastest_laptime               5381 non-null   timedelta64[ns]
#  4   avg_laptime                   5381 non-null   timedelta64[ns]
#  5   avg_laptime_milliseconds      5381 non-null   float64
#  6   slowest_laptime               5381 non-null   timedelta64[ns]
#  7   slowest_laptime_milliseconds  5381 non-null   int64
#  8   fastest_laptime_milliseconds  5381 non-null   int64
#  9   best_racePosition             5381 non-null   int64
#  10  avg_racePosition              5381 non-null   float64
#  11  worst_racePosition            5381 non-null   int64
#  12  fastestLapSpeed               5381 non-null   float64
# dtypes: float64(3), int64(7), timedelta64[ns](3)
# memory usage: 588.5 KB
